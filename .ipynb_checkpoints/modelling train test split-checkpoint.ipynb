# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn import preprocessing
from sklearn.naive_bayes import BernoulliNB
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import accuracy_score

# %%
all_df = pd.read_csv('dataset_all_category.csv')
all_df = all_df.reset_index(drop=True).drop(['Unnamed: 0'], axis=1)
all_df
# Out:
#               id                                         track_name  price  \
# 0      281656475                                    PAC-MAN Premium   3.99
# 1      281796108                          Evernote - stay organized   0.00
# 2      281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   0.00
# 3      282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   0.00
# 4      282935706                                              Bible   0.00
# ...          ...                                                ...    ...
# 6772  1187617475                                              Kubik   0.00
# 6773  1187682390                                  VR Roller-Coaster   0.00
# 6774  1187779532              Bret Michaels Emojis + Lyric Keyboard   1.99
# 6775  1187838770          VR Roller Coaster World - Virtual Reality   0.00
# 6776  1188375727                       Escape the Sweet Shop Series   0.00
#
#       cont_rating   prime_genre  vpp_lic  \
# 0               4         games        1
# 1               4  productivity        1
# 2               4       weather        1
# 3              12      shopping        1
# 4               4     reference        1
# ...           ...           ...      ...
# 6772            4         games        1
# 6773            4         games        1
# 6774            9     utilities        1
# 6775           12         games        1
# 6776            4         games        1
#
#                                                app_desc
# 0     save limited popular video arcade history worl...
# 1     let change way organize personal professional ...
# 2     popular free weather powered professional weat...
# 3     best way find anything need fashion new used b...
# 4     million around world people reading listening ...
# ...                                                 ...
# 6772  place falling correctly order clear left right...
# 6773  thrilling virtual reality roller coaster exper...
# 6774  rock star bret winner celebrity apprentice cha...
# 6775  roller coaster world cardboard veer best rolle...
# 6776  previous escape plus new game one cupcake shop...
#
# [6777 rows x 7 columns]

# %%
genre_list = list(set(all_df['prime_genre'].to_list()))
le = preprocessing.LabelEncoder()
le.fit(genre_list)
all_df['encode_class'] = all_df['prime_genre'].apply(lambda x: le.transform([x])[0])
all_df
# Out:
#               id                                         track_name  price  \
# 0      281656475                                    PAC-MAN Premium   3.99
# 1      281796108                          Evernote - stay organized   0.00
# 2      281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   0.00
# 3      282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   0.00
# 4      282935706                                              Bible   0.00
# ...          ...                                                ...    ...
# 6772  1187617475                                              Kubik   0.00
# 6773  1187682390                                  VR Roller-Coaster   0.00
# 6774  1187779532              Bret Michaels Emojis + Lyric Keyboard   1.99
# 6775  1187838770          VR Roller Coaster World - Virtual Reality   0.00
# 6776  1188375727                       Escape the Sweet Shop Series   0.00
#
#       cont_rating   prime_genre  vpp_lic  \
# 0               4         games        1
# 1               4  productivity        1
# 2               4       weather        1
# 3              12      shopping        1
# 4               4     reference        1
# ...           ...           ...      ...
# 6772            4         games        1
# 6773            4         games        1
# 6774            9     utilities        1
# 6775           12         games        1
# 6776            4         games        1
#
#                                                app_desc  encode_class
# 0     save limited popular video arcade history worl...             7
# 1     let change way organize personal professional ...            15
# 2     popular free weather powered professional weat...            22
# 3     best way find anything need fashion new used b...            17
# 4     million around world people reading listening ...            16
# ...                                                 ...           ...
# 6772  place falling correctly order clear left right...             7
# 6773  thrilling virtual reality roller coaster exper...             7
# 6774  rock star bret winner celebrity apprentice cha...            21
# 6775  roller coaster world cardboard veer best rolle...             7
# 6776  previous escape plus new game one cupcake shop...             7
#
# [6777 rows x 8 columns]

# %%
x_all_df = all_df.iloc[:, [2,3,5,6]]
y_all_df = all_df.iloc[:, [7]]

# %%
def tf_idf(text, max_feat=None):
    tfidf_vect = TfidfVectorizer(max_features=max_feat)
    tfidf_vect.fit(text)
    return tfidf_vect

# %%
base_vectorizer = tf_idf(all_df.app_desc, max_feat=30)

# %%
def join_feature(feature, tfidf):
    features = []
    transform = np.array(feature.iloc[:, [0,1,2]])
    for i,_ in enumerate(transform):
        concat = np.concatenate(
            [transform[i].reshape(-1), 
             tfidf[i].reshape(-1)]
        )
        features.append(concat)
    return np.array(features)

# %%
def build_ml(train, test, train_y, test_y, vectorizer):
    train_x_tfidf = vectorizer.fit_transform(train.app_desc).toarray()
    test_x_tfidf = vectorizer.fit_transform(test.app_desc).toarray()
    train_x = join_feature(train, train_x_tfidf)
    test_x = join_feature(test, test_x_tfidf)
    mnb = MultinomialNB()
    mnb.fit(train_x, train_y.ravel())
    predictions_mnb = mnb.predict(test_x)
    score_mlt = accuracy_score(predictions_mnb, test_y)*100
    bernoulli = BernoulliNB()
    bernoulli.fit(train_x, train_y.ravel())
    predictions_bernoulli = bernoulli.predict(test_x)
    fig, ax = plt.subplots(figsize=(20, 20))
    plot_confusion_matrix(bernoulli, test_x, test_y, normalize='true', cmap=plt.cm.Blues, ax=ax)
    plt.show()
    score_bernoulli = accuracy_score(predictions_bernoulli, test_y)*100
    print("acc score -> bernoulli : {} multinomial : {}".format(score_bernoulli, score_mlt))
    return score_mlt, score_bernoulli

# %%
train_inds, test_inds = next(StratifiedShuffleSplit(
    train_size=.70, n_splits=1, random_state = 42
).split(x_all_df, y_all_df, groups=all_df['encode_class']))

# %%
# train
x_all_train_df = all_df.iloc[train_inds, [2,3,5,6]]
y_all_train_df = all_df.iloc[train_inds, [7]]
# test
x_all_test_df = all_df.iloc[test_inds, [2,3,5,6]]
y_all_test_df = all_df.iloc[test_inds, [7]]

# %%
score_mlt, score_bernoulli = build_ml(
    train = x_all_train_df, 
    test = x_all_test_df, 
    train_y = np.array(y_all_train_df),
    test_y = np.array(y_all_test_df),
    vectorizer = base_vectorizer
)
# Out:
# acc score -> bernoulli : 49.852507374631266 multinomial : 52.50737463126843

# %%
games_df = pd.read_csv('dataset_binary_games.csv')
games_df = games_df.reset_index(drop=True).drop(['Unnamed: 0'], axis=1)
games_df
# Out:
#               id                                         track_name  price  \
# 0      302584613        Kindle – Read eBooks, Magazines & Textbooks   0.00
# 1      350480010                               eBook: War and Peace   3.99
# 2      366869252          OverDrive – Library eBooks and Audiobooks   0.00
# 3      369111608                                           iBunkoHD   6.99
# 4      379693831  Audible – audio books, original series & podcasts   0.00
# ...          ...                                                ...    ...
# 6235   924373886                Crossy Road - Endless Arcade Hopper   0.00
# 6236   608899141                          Cut the Rope: Time Travel   0.99
# 6237  1070525362    Cosmic Challenge: Best online space racing game   0.00
# 6238  1100810556  Hidden Expedition: Dawn of Prosperity - A Myst...   6.99
# 6239   367242040                                The Impossible Game   0.99
#
#       cont_rating prime_genre  vpp_lic  \
# 0               4        book        1
# 1               9        book        1
# 2               4        book        1
# 3              17        book        1
# 4               4        book        1
# ...           ...         ...      ...
# 6235            9       games        1
# 6236            4       games        1
# 6237            4       games        1
# 6238            9       games        1
# 6239            4       games        1
#
#                                                app_desc  is_games
# 0     turn kindle free kindle carry wherever go narr...         0
# 1     enjoy reading war peace day night multiple fon...         0
# 2     borrow streaming video library overdrive touch...         0
# 3     best way read comic realistic interface enjoy ...         0
# 4     welcome audible company home unmatched selecti...         0
# ...                                                 ...       ...
# 6235  apple design award winner chicken cross pigeon...         1
# 6236  join om back time feed candy cut rope time tra...         1
# 6237  space race competition space race different sp...         1
# 6238  pay play forever unusual signal vicinity old a...         1
# 6239  featured week us best selling live game comes ...         1
#
# [6240 rows x 8 columns]

# %%
x_games_df = games_df.iloc[:, [2,3,5,6]]
y_games_df = games_df.iloc[:, [7]]

# %%
train_inds, test_inds = next(StratifiedShuffleSplit(
    test_size=.30, n_splits=1, random_state = 42
).split(x_games_df, y_games_df, groups=games_df['is_games']))

# %%
# train
x_all_train_df = x_games_df.iloc[train_inds]
y_all_train_df = y_games_df.iloc[train_inds]
# test
x_all_test_df = x_games_df.iloc[test_inds]
y_all_test_df = y_games_df.iloc[test_inds]

# %%
score_mlt, score_bernoulli = build_ml(
    train = x_all_train_df, 
    test = x_all_test_df, 
    train_y = np.array(y_all_train_df),
    test_y = np.array(y_all_test_df),
    vectorizer = base_vectorizer
)
# Out:
# acc score -> bernoulli : 76.01495726495726 multinomial : 68.05555555555556
